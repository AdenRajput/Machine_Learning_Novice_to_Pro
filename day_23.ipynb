# %% [markdown]
# # Supervised Learning: Part#2

# %% [markdown]
# # 2. Decision Trees:
# - Classification
# - Regression

# %% [markdown]
# ### **Descision Tree Classifier:**

# %%
# decision tree on iris data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import plot_tree

# %%
#data
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
X = df.drop(columns='species')
y = df['species']

#splitting data with test size 30% and train size 70%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# model buiilding
dtm = DecisionTreeClassifier()

# %%
#train the model
dtm.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#test the model
y_pred = dtm.predict(X_test)

# %%
#evaluation
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Generate a classification report
print("Classification Report", classification_report(y_test, y_pred))

# Generate a confusion matrix
print("Confusion Matrix", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.00
# Classification Report               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
# Confusion Matrix [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]

# %%
plt.figure(figsize=(20,10))
plot_tree(dtm, filled=True)
plt.show()

# %%
# #plotting the tree with feature names and class names
# # Convert the index of the DataFrame to a list of feature names
# feature_names = list(X.columns)
# plt.figure(figsize=(20,10))
# plot_tree(dtm, feature_names, class_names=y.unique(), filled=True)
# plt.show()


# Convert the index of the DataFrame to a list of feature names
feature_names = list(X.columns)

# Plot the Decision Tree with feature names and class names
plt.figure(figsize=(20, 10))
plot_tree(dtm, feature_names=feature_names, class_names=[str(c) for c in y.unique()], filled=True)
plt.show()

# %%
#preedict with manual input
# Create a dictionary of features
flr = float(input("enter sepal length in cm: "))
fwr = float(input("enter sepal width in cm: "))
plr = float(input("enter petal length in cm: "))
pwr = float(input("enter petal width in cm: "))

sample = {
    'sepal_length': [flr],
    'sepal_width': [fwr],
    'petal_length': [plr],
    'petal_width': [pwr]
}

# Convert the dictionary to a DataFrame
sample_df = pd.DataFrame(sample)

# Make a prediction using the Decision Tree
pred = dtm.predict(sample_df)

print(f"The predicted species is {pred[0]}")
# Out:
# The predicted species is virginica
